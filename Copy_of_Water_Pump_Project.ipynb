# %% [markdown]
# # 1. Importing require libiraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 2. Importing and understanding the dataset

# %% [markdown]
# # Test dataset

# %%
try:
    from google.colab import files  # will fail outside Colab
    uploaded = files.upload()
    print("Uploaded files:", list(uploaded.keys()))
except Exception as e:
    print("If you're in Colab, this will work. Otherwise, skip to Option 2 or load from local path.")
# Out:
#      <input type="file" id="files-6bffbce6-0302-4608-82ea-178c28ef1930" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6bffbce6-0302-4608-82ea-178c28ef1930">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
csv_path = 'Test set value WP.csv'
if csv_path:
    test_df = pd.read_csv(csv_path)

# %%
test_df.head()
# Out:
#       id  amount_tsh date_recorded                  funder  gps_height  \
# 0  50785         0.0    2013-02-04                    Dmdd        1996
# 1  51630         0.0    2013-02-04  Government Of Tanzania        1569
# 2  17168         0.0    2013-02-01                     NaN        1567
# 3  45559         0.0    2013-01-22              Finn Water         267
# 4  49871       500.0    2013-03-27                  Bruder        1260
#
#     installer  longitude   latitude                 wpt_name  num_private  \
# 0        DMDD  35.290799  -4.059696  Dinamu Secondary School            0
# 1         DWE  36.656709  -3.309214                  Kimnyak            0
# 2         NaN  34.767863  -5.004344           Puma Secondary            0
# 3  FINN WATER  38.058046  -9.418672           Kwa Mzee Pange            0
# 4      BRUDER  35.006123 -10.950412          Kwa Mzee Turuka            0
#
#    ... payment_type water_quality quality_group      quantity  quantity_group  \
# ...

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14850 entries, 0 to 14849
# Data columns (total 40 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     14850 non-null  int64
#  1   amount_tsh             14850 non-null  float64
#  2   date_recorded          14850 non-null  object
#  3   funder                 13980 non-null  object
#  4   gps_height             14850 non-null  int64
#  5   installer              13973 non-null  object
#  6   longitude              14850 non-null  float64
#  7   latitude               14850 non-null  float64
#  8   wpt_name               14850 non-null  object
#  9   num_private            14850 non-null  int64
#  10  basin                  14850 non-null  object
#  11  subvillage             14751 non-null  object
#  12  region                 14850 non-null  object
#  13  region_code            14850 non-null  int64
# ...

# %%
categorical_values = []
for column in test_df.columns:
    print('==============================')
    print(f"{column} : {test_df[column].unique()}")
    if len(test_df[column].unique()) <= 10:
        categorical_values.append(column)
# Out:
# ...
# id : [50785 51630 17168 ... 28749 33492 68707]
# ...
# amount_tsh : [0.00e+00 5.00e+02 3.00e+01 5.00e+00 1.00e+03 1.20e+03 2.00e+02 2.00e+01
#  5.00e+01 1.50e+03 2.40e+03 7.00e+00 7.50e+03 2.00e+03 3.00e+02 1.00e+02
#  1.00e+01 2.50e+02 4.00e+03 3.00e+03 2.50e+03 2.50e+01 6.00e+00 4.00e+01
#  7.50e+02 4.00e+02 6.00e+02 5.00e+03 1.50e+02 6.00e+03 3.30e+01 1.80e+04
#  2.20e+03 1.20e+04 3.60e+03 8.00e+03 7.00e+02 4.70e+03 4.50e+02 6.00e+01
#  1.00e+04 1.50e+01 2.00e+04 6.50e+03 7.00e+01 3.00e+04 2.50e+04 3.50e+04
#  1.50e+04 2.00e+05 1.00e+05 7.00e+04 2.00e-01 1.40e+04 7.20e+03 3.50e+03
#  2.00e+00 4.00e+04 3.50e+02 3.50e+01 7.00e+03 3.00e+00 2.55e+03 5.00e+04
#  6.00e+04 5.00e-01 5.50e+02 2.80e+03]
# ...
# date_recorded : ['2013-02-04' '2013-02-01' '2013-01-22' '2013-03-27' '2013-03-04'
#  '2011-03-02' '2013-01-25' '2013-01-23' '2013-03-18' '2013-10-03'
#  '2013-02-27' '2012-10-11' '2011-07-29' '2013-06-03' '2011-02-24'
#  '2011-03-11' '2012-10-06' '2013-02-02' '2013-03-12' '2011-03-07'
# ...

# %%
test_df.isnull().sum()
# Out:
# id                          0
# amount_tsh                  0
# date_recorded               0
# funder                    870
# gps_height                  0
# installer                 877
# longitude                   0
# latitude                    0
# wpt_name                    0
# num_private                 0
# basin                       0
# subvillage                 99
# region                      0
# region_code                 0
# district_code               0
# lga                         0
# ward                        0
# population                  0
# public_meeting            821
# recorded_by                 0
# scheme_management         969
# scheme_name              7242
# permit                    737
# construction_year           0
# extraction_type             0
# extraction_type_group       0
# extraction_type_class       0
# management                  0
# management_group            0
# payment                     0
# payment_type                0
# ...

# %%
test_df['funder'].unique()
# Out:
# array(['Dmdd', 'Government Of Tanzania', nan, 'Finn Water', 'Bruder',
#        'Finw', 'Unicef', 'Lawatefuka Water Supply', 'Germany Republi',
#        'World Vision', 'World Bank', 'Ministry Of Water', 'Danida',
#        'Rural Water Supply And Sanitat', '0', 'Dwe', 'Tasaf',
#        'Mwanashila', 'Tz Japan', 'Germany', 'Water', 'Dwsp', 'Bffs',
#        'Private Individual', 'Tlc', 'Mkinga Distric Coun', 'Nethalan',
#        'Jaica', 'Rotary Club', 'Morovian', 'Isf/government', 'Rc Church',
#        'Dwssp', 'Jica', 'Hesawa', 'Concern', 'People Of Japan',
#        'Solidarm', 'Kkkt', 'Adra', 'Rudep', 'Water Aid /sema', 'Rc',
#        'Professor Ben Ohio University', 'Kibaha Town Council', 'Idydc',
#        'Ki', 'African', 'Adp', 'Si', 'France', 'Kadp',
#        'Village Council/ Haydom Luther', 'Tdft', 'Norad', 'Rw Ssp',
#        'Franc', 'Rwssp', 'Wua', 'Unice', 'Ces (gmbh)', 'Fathe',
#        'Oikos E.Afrika', 'M', 'Plan International', 'Bsf', 'Mws',
# ...

# %%
test_df['funder'].mode()
# Out:
# 0    Government Of Tanzania
# Name: funder, dtype: object

# %%
test_df['funder'] = test_df.funder.fillna(test_df.funder.mode()[0])

# %%
test_df['installer'].unique()
# Out:
# array(['DMDD', 'DWE', nan, ..., 'O &', 'Central government/TLC', 'LIVI'],
#       dtype=object)

# %%
test_df['installer'].mode()
# Out:
# 0    DWE
# Name: installer, dtype: object

# %%
test_df['installer'] = test_df.installer.fillna(test_df.installer.mode()[0])

# %%
test_df['subvillage'].unique()
# Out:
# array(['Magoma', 'Kimnyak', 'Msatu', ..., 'Kipengele', 'Kosoro', 'Kamba'],
#       dtype=object)

# %%
test_df['subvillage'].mode()
# Out:
# 0    Shuleni
# Name: subvillage, dtype: object

# %%
test_df['subvillage'] = test_df.subvillage.fillna(test_df.subvillage.mode()[0])

# %%
test_df['public_meeting'].unique()
# Out:
# array([True, nan, False], dtype=object)

# %%
test_df['public_meeting'] = test_df.public_meeting.fillna(test_df.public_meeting.mode()[0]).infer_objects(copy=False)
# Out:
# /tmp/ipykernel_24110/1725822419.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   test_df['public_meeting'] = test_df.public_meeting.fillna(test_df.public_meeting.mode()[0]).infer_objects(copy=False)

# %%
test_df['scheme_management'].unique()
# Out:
# array(['Parastatal', 'VWC', 'Water Board', nan, 'Other', 'SWC', 'WUG',
#        'WUA', 'Water authority', 'Company', 'Private operator', 'Trust'],
#       dtype=object)

# %%
test_df['scheme_management'] = test_df.scheme_management.fillna(test_df.scheme_management.mode()[0])

# %%
test_df['scheme_name'].unique()
# Out:
# array([nan, 'TPRI pipe line', 'P', ..., 'BL Vetenary', 'MIGA',
#        'Mbwasa water supply'], dtype=object)

# %%
test_df['scheme_name'] = test_df.scheme_name.fillna(test_df.scheme_name.mode()[0])

# %%
test_df['permit'].unique()
# Out:
# array([True, nan, False], dtype=object)

# %%
test_df['permit']= test_df.permit.fillna(test_df.permit.mode()[0]).infer_objects(copy=False)
# Out:
# /tmp/ipykernel_24110/3231996954.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   test_df['permit']= test_df.permit.fillna(test_df.permit.mode()[0]).infer_objects(copy=False)

# %%
test_df.isnull().sum()
# Out:
# id                       0
# amount_tsh               0
# date_recorded            0
# funder                   0
# gps_height               0
# installer                0
# longitude                0
# latitude                 0
# wpt_name                 0
# num_private              0
# basin                    0
# subvillage               0
# region                   0
# region_code              0
# district_code            0
# lga                      0
# ward                     0
# population               0
# public_meeting           0
# recorded_by              0
# scheme_management        0
# scheme_name              0
# permit                   0
# construction_year        0
# extraction_type          0
# extraction_type_group    0
# extraction_type_class    0
# management               0
# management_group         0
# payment                  0
# payment_type             0
# water_quality            0
# quality_group            0
# quantity                 0
# ...

# %%
test_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
try:
    from google.colab import files  # will fail outside Colab
    uploaded = files.upload()
    print("Uploaded files:", list(uploaded.keys()))
except Exception as e:
    print("If you're in Colab, this will work. Otherwise, skip to Option 2 or load from local path.")
# Out:
#      <input type="file" id="files-2847bab1-97f1-4b7f-9a24-01ecf896efe0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2847bab1-97f1-4b7f-9a24-01ecf896efe0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
csv_path = 'Training set Value.csv'
if csv_path:
    df = pd.read_csv(csv_path)

# %% [markdown]
# Shape of the dataset

# %%
df.shape
# Out:
# (59400, 40)

# %% [markdown]
# Printing out a few columns

# %%
df.head()
# Out:
#       id  amount_tsh date_recorded        funder  gps_height     installer  \
# 0  69572      6000.0    2011-03-14         Roman        1390         Roman
# 1   8776         0.0    2013-03-06       Grumeti        1399       GRUMETI
# 2  34310        25.0    2013-02-25  Lottery Club         686  World vision
# 3  67743         0.0    2013-01-28        Unicef         263        UNICEF
# 4  19728         0.0    2011-07-13   Action In A           0       Artisan
#
#    longitude   latitude              wpt_name  num_private  ... payment_type  \
# 0  34.938093  -9.856322                  none            0  ...     annually
# 1  34.698766  -2.147466              Zahanati            0  ...    never pay
# 2  37.460664  -3.821329           Kwa Mahundi            0  ...   per bucket
# 3  38.486161 -11.155298  Zahanati Ya Nanyumbu            0  ...    never pay
# 4  31.130847  -1.825359               Shuleni            0  ...    never pay
#
# ...

# %%
df.tail()
# Out:
#           id  amount_tsh date_recorded           funder  gps_height installer  \
# 59395  60739        10.0    2013-05-03  Germany Republi        1210       CES
# 59396  27263      4700.0    2011-05-07      Cefa-njombe        1212      Cefa
# 59397  37057         0.0    2011-04-11              NaN           0       NaN
# 59398  31282         0.0    2011-03-08            Malec           0      Musa
# 59399  26348         0.0    2011-03-23       World Bank         191     World
#
#        longitude  latitude             wpt_name  num_private  ...  \
# 59395  37.169807 -3.253847  Area Three Namba 27            0  ...
# 59396  35.249991 -9.070629    Kwa Yahona Kuvala            0  ...
# 59397  34.017087 -8.750434              Mashine            0  ...
# 59398  35.861315 -6.378573               Mshoro            0  ...
# 59399  38.104048 -6.747464      Kwa Mzee Lugawa            0  ...
#
#       payment_type water_quality quality_group      quantity  quantity_group  \
# ...

# %%
df.sample(5)
# Out:
#           id  amount_tsh date_recorded                          funder  \
# 41652  41342       100.0    2013-03-18                               0
# 11463  57617         0.0    2013-03-25  Oikos E .Africa/european Union
# 47111  46836         0.0    2011-03-11                            Undp
# 25977  58782         0.0    2013-02-07          Government Of Tanzania
# 17397   9512         0.0    2011-03-13          Government Of Tanzania
#
#        gps_height        installer  longitude  latitude    wpt_name  \
# 41652          32                0  39.162669 -6.912740  Kwa Mpemba
# 11463        1417  Oikos E .Africa  36.918574 -3.236425       Paulo
# 47111        1787            MLADE  34.477526 -9.686870        none
# 25977           0              DWE  33.286845 -4.653843   Sekondari
# 17397         171              DWE  38.801542 -5.084752      Konani
#
#        num_private  ... payment_type    water_quality quality_group  quantity  \
# ...

# %% [markdown]
# # 3. Exploration Data Analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59400 entries, 0 to 59399
# Data columns (total 40 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     59400 non-null  int64
#  1   amount_tsh             59400 non-null  float64
#  2   date_recorded          59400 non-null  object
#  3   funder                 55763 non-null  object
#  4   gps_height             59400 non-null  int64
#  5   installer              55745 non-null  object
#  6   longitude              59400 non-null  float64
#  7   latitude               59400 non-null  float64
#  8   wpt_name               59398 non-null  object
#  9   num_private            59400 non-null  int64
#  10  basin                  59400 non-null  object
#  11  subvillage             59029 non-null  object
#  12  region                 59400 non-null  object
#  13  region_code            59400 non-null  int64
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# id                           0
# amount_tsh                   0
# date_recorded                0
# funder                    3637
# gps_height                   0
# installer                 3655
# longitude                    0
# latitude                     0
# wpt_name                     2
# num_private                  0
# basin                        0
# subvillage                 371
# region                       0
# region_code                  0
# district_code                0
# lga                          0
# ward                         0
# population                   0
# public_meeting            3334
# recorded_by                  0
# scheme_management         3878
# scheme_name              28810
# permit                    3056
# construction_year            0
# extraction_type              0
# extraction_type_group        0
# extraction_type_class        0
# management                   0
# management_group             0
# payment                      0
# ...

# %%
df['funder'] = df.funder.fillna(df.funder.mode()[0])
df['installer'] = df.installer.fillna(df.installer.mode()[0])
df['subvillage'] = df.subvillage.fillna(df.subvillage.mode()[0])
df['public_meeting'] = df.public_meeting.fillna(df.public_meeting.mode()[0]).infer_objects(copy=False)
df['scheme_management'] = df.scheme_management.fillna(df.scheme_management.mode()[0])
df['scheme_name'] = df.scheme_name.fillna(df.scheme_name.mode()[0])
df['permit']= df.permit.fillna(df.permit.mode()[0]).infer_objects(copy=False)
# Out:
# /tmp/ipykernel_24110/1512209040.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['public_meeting'] = df.public_meeting.fillna(df.public_meeting.mode()[0]).infer_objects(copy=False)
# /tmp/ipykernel_24110/1512209040.py:7: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['permit']= df.permit.fillna(df.permit.mode()[0]).infer_objects(copy=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59400 entries, 0 to 59399
# Data columns (total 40 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     59400 non-null  int64
#  1   amount_tsh             59400 non-null  float64
#  2   date_recorded          59400 non-null  object
#  3   funder                 59400 non-null  object
#  4   gps_height             59400 non-null  int64
#  5   installer              59400 non-null  object
#  6   longitude              59400 non-null  float64
#  7   latitude               59400 non-null  float64
#  8   wpt_name               59398 non-null  object
#  9   num_private            59400 non-null  int64
#  10  basin                  59400 non-null  object
#  11  subvillage             59400 non-null  object
#  12  region                 59400 non-null  object
#  13  region_code            59400 non-null  int64
# ...

# %%
df.head(100)
# Out:
#        id  amount_tsh date_recorded                  funder  gps_height  \
# 0   69572      6000.0    2011-03-14                   Roman        1390
# 1    8776         0.0    2013-03-06                 Grumeti        1399
# 2   34310        25.0    2013-02-25            Lottery Club         686
# 3   67743         0.0    2013-01-28                  Unicef         263
# 4   19728         0.0    2011-07-13             Action In A           0
# ..    ...         ...           ...                     ...         ...
# 95  26419       250.0    2013-01-27                  Danida        1471
# 96  68554       500.0    2013-02-11  Government Of Tanzania        1274
# 97  29083         0.0    2011-08-04                 Mzee Sh           0
# 98  33379         0.0    2013-02-19                  Danida        1000
# 99  43206         0.0    2012-10-06                    Aict           0
#
#        installer  longitude   latitude              wpt_name  num_private  \
# ...

# %% [markdown]
# Description

# %%
df.describe().T
# Out:
#                      count          mean           std       min  \
# id                 59400.0  37115.131768  21453.128371   0.00000
# amount_tsh         59400.0    317.650385   2997.574558   0.00000
# gps_height         59400.0    668.297239    693.116350 -90.00000
# longitude          59400.0     34.077427      6.567432   0.00000
# latitude           59400.0     -5.706033      2.946019 -11.64944
# num_private        59400.0      0.474141     12.236230   0.00000
# region_code        59400.0     15.297003     17.587406   1.00000
# district_code      59400.0      5.629747      9.633649   0.00000
# population         59400.0    179.909983    471.482176   0.00000
# construction_year  59400.0   1300.652475    951.620547   0.00000
#
#                             25%           50%           75%           max
# id                 18519.750000  37061.500000  55656.500000  7.424700e+04
# amount_tsh             0.000000      0.000000     20.000000  3.500000e+05
# ...

# %% [markdown]
# Analysing the "target" variable
